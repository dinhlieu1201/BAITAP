# %%
#W3A2
a = int(input('Nhập giá trị a: '))
b = int(input('Nhập giá trị b: '))
print('Trước khi hoán đổi: a =',a,' b = ',b)
# Hoán đổi bằng XOR
a = a ^ b
b = a ^ b
a = a ^ b

print('Sau khi hoán đổi: a =',a, 'b =',b)
# Out:
# Trước khi hoán đổi: a = 6  b =  9
# Sau khi hoán đổi: a = 9 b = 6

# %%
#W3A3
n = int(input('Nhập số nguyên dương n:'))
if n > 0 and (n & (n - 1)) == 0:
    print(n,'là lũy thừa của 2')
else:
    print(n,'không phải là lũy thừa của 2')
# Out:
# 5 không phải là lũy thừa của 2

# %%
#W3A4
m, n = map(int, input('nhập lần lượt 2 số m,n:').split())
chia=m//n
print(chia)
# Out:
# 3

# %%
#W3A4 cách 2 
import math
m, n = map(float, input('Nhập lần lượt 2 số m,n:').split())
chia = math.floor(m / n)
print(chia)
# Out:
# 3

# %%
#W3A5
import math
m, n = map(float, input('Nhập lần lượt 2 số mn,n:').split())
chia = math.ceil(m / n)
print(chia)
# Out:
# 1

# %%
#W3A6
n = int(input('Nhập vào một số:'))
if n % 2 == 0:
    print('Even')
else:
    print('Odd')
# Out:
# Odd

# %%
#W3A7
a, b = map(int, input('Nhập vào lần lượt 2 số a,b:').split())
if a < 0 and b < 0:
    print('Yes')
else:
    print('No')
# Out:
# No

# %%
#W3A8
a = input('Nhập vào chuỗi a:')
b = input('Nhập vào chuỗi b:')
if len(a) > len(b):
    print('True')
else:
    print('False')
# Out:
# False

# %%
#W3A9
a, b, c = map(int, input('nhập vào lần lượt 3 cạnh của tam giác:').split())
if a + b > c and a + c > b and b + c > a:
    print('Yes')
else:
    print('No')
# Out:
# Yes

# %%
#W3A10
a, b, c, d = map(int, input('Nhập vào 4 số nguyên:').split())
print(max(a, b, c, d))
# Out:
# 7

# %%
#W3A11
a,b,c = map(int,input('Nhập vào 3 số nguyên dương:').split())
if a+b>c and a+c>b and b+c>a :
    if a==b==c:
        print('Đây là tam giác đều')
    elif a==b or a==c or b==c :
        print('Đây là tam giác cân')
    else:
        print('Đây là tam giác thường')
else:
    print('Không phải 3 cạnh của tam giác')
# Out:
# Không phải 3 cạnh của tam giác

# %%
#W3A12
n=int(input('Nhập vào một số nguyên dương:'))
if n>0:
    if n % 4==0 and n % 100 !=0 or n%400==0:
        print('Yes')
    else:
        print('No')
else:
    print('Vui lòng nhập số dương')
# Out:
# Yes

# %%
#W3A14
a,b = map(float,input('Nhập vào 2 số thực:').split())
if a==0:
    if b==0:
        print('Phương trình có vô số nghiệm')
    else:
        print('Phương trình vô nghiệm')
else:
    x=-b/a
    print(f'{x:.2f}')
# Out:
# 2.00

# %%
#W3A15
n=float(input('nhập vào điểm số :'))
if n>=8.0:
    print('giỏi')
else:
    if n>=6.5 :
        print('Khá')
    else:
        if n>=5.0:
            print('Trung bình')
        else:
            print('Yếu')
# Out:
# Yếu

# %%
#W3A17
a,b,c,d= map(float,input('Nhập vào 4 số :').split())
if a == 0:
    print('Không phải cấp số nhân')  
else:
    if b % a != 0:
        print('Không phải cấp số nhân')  
    else:
        q = b // a 
        if b * q == c and c * q == d:
            print('Là cấp số nhân')
        else:
            print('Không phải cấp số nhân')
# Out:
# Là cấp số nhân
