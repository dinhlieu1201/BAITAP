# %%
#W2A1
print('Hello World!')
# Out:
# Hello World!

# %%
#W2A2
n=str(input('Hãy nhập tên của bạn:'))
print('Xin chào',n)
# Out:
# Xin chào Liễu

# %%
#W2A3
a=int(input('nhập vào số nguyên a:'))
b=int(input('nhập vào số nguyên b:'))
tong= a+b
hieu=a-b
tich=a*b
phannguyen=a//b
phandu=a%b
chia=a/b
print('Tổng:',tong)
print('Hiệu:',hieu)
print('Tích:',tich)
print('Chia lấy phần nguyên:',phannguyen)
print('Chia lấy phần dư:',phandu)
print('Chia lấy kết quả thực:',chia)
# Out:
# Tổng: 15
# Hiệu: 5
# Tích: 50
# Chia lấy phần nguyên: 2
# Chia lấy phần dư: 0
# Chia lấy kết quả thực: 2.0

# %%
#W2A4
a1, b1, c1, a2, b2, a3 = map(float, input().split())
TB = ((a1 + b1 + c1) + (a2 + b2) * 2 + a3 * 3) / 10
print(f"{TB:.1f}")
# Out:
# 7.2

# %%
#W2A5
a,b= map(float,input().split())
kq=a**b
print(kq)
# Out:
# 61382594.93549351

# %%
#W2A6
n=input()
unicode=ord(n)
print(unicode)
chuhoa=chr(unicode-32)  #trong bảng chữ cái, chữ cái hoa cách chữ cái thường 32 đơn vị
print(chuhoa)
# Out:
# 102
# F

# %%
#W2A6 cách 2
n=input()
print(ord(n))
print(n.upper())
# Out:
# 116
# T

# %%
#W2A7
A = ((13 ** 2) * 3) + 5
B = 13**2*3 + 5
print(A,B)
# Out:
# 512 512

# %%
#W2A8 
C=float(input('Nhập nhiệt độ Celsius:'))
F=9/5*C+32
print(f'{F:.2f}')
# Out:
# 74.30

# %%
#W2A9
x=float(input('Nhập giá đồng hồ:'))
tong=x*0.1+x*0.3+10
print(f'{tong:.2f}')
# Out:
# 32.40

# %%
#W2A10
ten=(input('Nhap vao ten 3 nguoi:').split())
ten.reverse()
print(ten[0],ten[1],ten[2])
# Out:
# Oanh Anh Quyen

# %%
#W2A11
h=int(input('Nhap so gio:'))
m=int(input('Nhap so phut:'))
s=h*3600+m*60
print(h,'gio',m,'phut =',s,'giay')
# Out:
# 5 gio 4 phut = 18240 giay

# %%
#W2A12
