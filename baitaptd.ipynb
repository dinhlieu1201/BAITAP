# %%
#Bài 1
n = int(input('Nhap so nguyen n :  '))
print('So gap doi cua n la :  ', n*2)
# Out:
# So gap doi cua n la :   0

# %%
#Bài 2
a = float(input('Nhap chieu rong a cua khu dat : '))
b = float(input('Nhap chieu dai b cua khu dat : '))
#bán kính hình tròn là: 
r= a/2
# Diện tích khu đất hình chữ nhật là:
S1= a*b 
#Diện tích khu đất hình tròn là:
S2=r**2*3.14
#Diện tích còn lại để trồng cây là:
S=S1-S2
print(' Phần diện tích còn lại để trồng cây là: ',round(S,2))
# Out:
#  Phần diện tích còn lại để trồng cây là:  15.44

# %%
#Bài 3
c=(input('Nhap mot ky tu: '))
if len(c) != 1:
    print('Vui long chi nhap mot ky tu duy nhat!')
else:
    if c.isupper():
        print('Chu thuong tuong ung la:', c.lower())
    elif c.islower():
        print('Chu hoa tuong ung la:', c.upper())
    else:
        print('Ky tu nhap vao khong phai chu cai')
# Out:
# Chu hoa tuong ung la: E

# %%
#Bài 4
c=input('Nhap vao mot ky tu: ')
if len(c) != 1:
    print('Vui long chi nhap mot ky tu duy nhat')
else:
    if c.isalpha():
        print(c,'la ky tu alphabet')
    else:
        print(c,'khong phai la ky tu alphabet')
# Out:
# 5 khong phai la ky tu alphabet

# %%
#Bài 5
c=input('Nhap vao mot chu cai hoa:')
if len(c) != 1 or not c.isupper():
    print('ky tu nhap vao khong phai mot chu cai hoa')
else:
    if c== 'A':
        truoc = 'z'
    else:
        thuong = c.lower()
        truoc= chr(ord(thuong)-1)
    print('chu cai thuong lien truoc',c.lower(), 'la', truoc)
# Out:
# ky tu nhap vao khong phai mot chu cai hoa

# %%
#Bài 6
import math
a=float(input('a='))
b=float(input('b='))
c=float(input('c='))
s=0
p=0
#p là nửa chu vi tam giác
if a + b > c and a + c > b and b + c > a:
    p=(a+b+c)/2
    s= math.sqrt(p*(p-a)*(p-b)*(p-c))
    print('Dien tich tam giac la:',s)
else:
    print('day khong phai la 3 canh cua mot tam giac')
# Out:
# Dien tich tam giac la: 17.320508075688775
