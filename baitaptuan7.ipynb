# %%
#W7A1
def binary_search(arr, target):
    n=len(arr)
    left,right=0,n-1
    while left <= right:
        mid = (left + right) // 2

        if arr[mid] == target:
            return mid
        elif arr[mid] > target:
            right = mid - 1
        else:
            left = mid + 1

    return -1
arr=list(map(int,input().split()))
target=int(input())
print(binary_search(arr,target))
# Out:
# 2

# %%
#W7A2
def count_occurrences(arr, x):
    count = 0
    for v in arr:
        if v == x:
            count += 1
    return count

arr=list(map(int,input().split()))
x=int(input())
print(count_occurrences(arr,x))
# Out:
# 3

# %%
#W7A3
#nổi bọt
def bubble_sort(arr):
    n = len(arr)
    for i in range(n - 1):
        for j in range(n - 1 - i):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
    return arr
#Selection Sort
def selection_sort(arr):
    n = len(arr)
    for i in range(n - 1):
        min_idx = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_idx]:
                min_idx = j
        arr[i], arr[min_idx] = arr[min_idx], arr[i]
    return arr

# %%
#W7A4
def most_frequent(arr):

    nhieunhat=0
    kq= None
    for i in range(len(arr)):
        dem=0
        for j in range(len(arr)):
            if arr[j]==arr[i]:
                dem+=1
        if dem>nhieunhat:
            nhieunhat=dem
            kq=arr[i]
    return kq
arr=list(map(int,input().split()))
print(most_frequent(arr))
# Out:
# 3

# %%
#W7A5
arr = list(map(int, input().split()))
X = int(input())
dem=0
n=len(arr)
for i in range(n):
    for j in range(i+1,n):
        if arr[i]+arr[j]==X:
            dem+=1
print(dem)
# Out:
# 14

# %%
#W7A6
n=int(input())
arr=[]
for _ in range(n):
    day=list(map(int,input().split()))
    arr.append(day)
d=[]
for day in arr:
    for x in day:
        d.append(x)
print(d)
# Out:
# [1, 2, 3, 4]

# %%
#W7A7
nums=list(map(int,input().split()))
n=len(nums)
dp=[1]*n
for i in range(n):
    for j in range(i):
        if nums[j]>nums[i]:
            dp[i]=max(dp[i],dp[j]+1)
print(max(dp))
# Out:
# 4

# %%
#W7A9
nums=list(map(int,input().split()))
d=[]
n=len(nums)
for i in range(n):
    dem=0
    for j in range(i+1,n):
        if nums[i]>nums[j]:
            dem+=1
    d.append(dem)
print(d)
# Out:
# [2, 1, 1, 0]

# %%
#W7A11
s=input()
key=input()
dem=0
for i in s.split():
    if i==key:
        dem+=1
print(dem)
# Out:
# 1

# %%
#W7A12
cumtu=[]
dic=['A','B','C','D']
for i in range(4):
    s=input()
    cumtu.append((s,dic[i]))
cumtu.sort()
print(' '.join(dic for _, dic in cumtu))
# Out:
# B A C D
