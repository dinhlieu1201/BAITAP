# %%
#Bài 1
n = int(input('Nhap mot so nguyen'))
if n % 2 == 0:
    print(n,'là số chẵn')
else:
    print(n,'là số lẻ')
# Out:
# 6 là số chẵn

# %%
#Bài 2
n=int(input('nhap mot so nguyen:'))
if n % 5 ==0:
    print('True')
else:
    print('False')
# Out:
# False

# %%
#Bài 3
n=int(input('Nhap vao mot so nguyen:'))
if n%3==0 and n%5==0:
    print('True')
else:
    print('False')
# Out:
# False
